# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data_osn = pd.read_csv('osn.csv')
data_osn
# Out:
#        Unnamed: 0            Nama Peserta Gender  \
# 0               0    Gangsar Lintas Damai      L
# 1               1  Muhammad Khairul Ihsan      L
# 2               2               Farhannur      L
# 3               3        Muhammad Fathoni      L
# 4               4               Rahmat MI      L
# ...           ...                     ...    ...
# 19322       19322    Fitri Julia Simamora      P
# 19323       19323    Jonathan Kevin Aruan      L
# 19324       19324       Mely Winda Sihite      P
# 19325       19325           Jelita Fazira      P
# 19326       19326   Pether Kanisius Gajah      L
#
#                             Sekolah        Provinsi                 Kab/Kota  \
# 0                 MA Amanatul Ummah      Jawa Timur            Kota Surabaya
# 1                  MAN 1 Banda Aceh            Aceh          Kota Banda Aceh
# 2                  MAN 1 Banda Aceh            Aceh          Kota Banda Aceh
# 3                  MAN 1 Banda Aceh            Aceh          Kota Banda Aceh
# 4                  MAN 1 Banda Aceh            Aceh          Kota Banda Aceh
# ...                             ...             ...                      ...
# 19322           SMPN 4 Doloksanggul  Sumatera Utara  Kab. Humbang Hasundutan
# 19323                SMPN 6 Sentajo            Riau    Kab. Kuantan Singingi
# 19324           SMPN 4 Doloksanggul  Sumatera Utara  Kab. Humbang Hasundutan
# 19325  SMPN 4 Pantai Labu Satu Atap  Sumatera Utara        Kab. Deli Serdang
# 19326             SMPN 4 Parlilitan  Sumatera Utara  Kab. Humbang Hasundutan
#
#            Bidang Jenjang Lomba Jenjang Sekolah  Kelas      Medali  \
# 0         Biologi           SMA             SMA   11.0  Partisipan
# 1         Ekonomi           SMA             SMA   11.0  Partisipan
# 2         Ekonomi           SMA             SMA   11.0        Emas
# 3          Fisika           SMA             SMA   11.0  Partisipan
# 4           Kimia           SMA             SMA   11.0  Partisipan
# ...           ...           ...             ...    ...         ...
# 19322  Matematika           SMP             SMP    7.0  Partisipan
# 19323         IPS           SMP             SMP    NaN  Partisipan
# 19324  Matematika           SMP             SMP    7.0  Partisipan
# 19325         IPS           SMP             SMP    NaN  Partisipan
# 19326         IPS           SMP             SMP    NaN  Partisipan
#
#       Prize Tambahan  Tahun
# 0                NaN   2016
# 1                NaN   2021
# 2                NaN   2022
# 3                NaN   2022
# 4                NaN   2022
# ...              ...    ...
# 19322            NaN   2024
# 19323            NaN   2016
# 19324            NaN   2024
# 19325            NaN   2021
# 19326            NaN   2020
#
# [19327 rows x 13 columns]

# %%
data_osn = pd.read_csv('osn.csv')

kategori_sma_inf = data_osn[(data_osn['Jenjang Lomba'] == 'SMA') & (data_osn['Bidang'] == 'Informatika')]

kategori_sma_inf_reset = kategori_sma_inf.reset_index(drop=True)


if 'Unnamed: 0' in kategori_sma_inf_reset.columns:
    del kategori_sma_inf_reset['Unnamed: 0']


urutan_medali = {
    'Emas': 1,
    'Perak': 2,
    'Perunggu': 3,
    'Peserta': 4,
}


kategori_sma_inf_reset.loc[:, 'Peringkat'] = kategori_sma_inf_reset['Medali'].map(urutan_medali)


kategori_sma_inf_sorted = kategori_sma_inf_reset.sort_values(by='Peringkat').reset_index(drop=True)
kategori_sma_inf_sorted
# Out:
#                     Nama Peserta Gender  \
# 0        Albert Yulius Ramahalim      L
# 1         Rama Aryasuta Pangestu      L
# 2                   Moses Mayer       L
# 3              Nicholas Patrick       L
# 4                   Nathan Allan      L
# ...                          ...    ...
# 1482   Muhammad Salman Al-Farisi      L
# 1483  Shalahuddin Akbar Aviecena      L
# 1484                   A R Yamin      L
# 1485         Radhya Cahya Kusuma      L
# 1486          Zikru Akbar Isnain      P
#
#                                         Sekolah          Provinsi  \
# 0                             SMA Katolik Ricci       DKI Jakarta
# 1                           SMA Kolese Kanisius       DKI Jakarta
# 2              SMA Jakarta Intercultural School       DKI Jakarta
# 3                SMP Cita Hati Christian School        Jawa Timur
# 4                           SMP Kolese Kanisius       DKI Jakarta
# ...                                         ...               ...
# 1482                           SMPN 2 Pamekasan        Jawa Timur
# 1483  SMA Yayasan Pendidikan Vidya Dahana Patra  Kalimantan Timur
# 1484                           SMPN 2 Pamekasan        Jawa Timur
# 1485                          SMPN 8 Yogyakarta     DI Yogyakarta
# 1486                        SMAN 8 Kota Ternate      Maluku Utara
#
#                   Kab/Kota       Bidang Jenjang Lomba Jenjang Sekolah  Kelas  \
# 0       Kota Jakarta Barat  Informatika           SMA             SMA   11.0
# 1       Kota Jakarta Pusat  Informatika           SMA             SMA   10.0
# 2     Kota Jakarta Selatan  Informatika           SMA             SMA   11.0
# 3            Kota Surabaya  Informatika           SMA             SMP    9.0
# 4       Kota Jakarta Pusat  Informatika           SMA             SMP    8.0
# ...                    ...          ...           ...             ...    ...
# 1482        Kab. Pamekasan  Informatika           SMA             SMP    9.0
# 1483          Kota Bontang  Informatika           SMA             SMA   11.0
# 1484        Kab. Pamekasan  Informatika           SMA             SMP    9.0
# 1485       Kota Yogyakarta  Informatika           SMA             SMP    9.0
# 1486          Kota Ternate  Informatika           SMA             SMA   11.0
#
#           Medali Prize Tambahan  Tahun  Peringkat
# 0           Emas            NaN   2021        1.0
# 1           Emas            NaN   2019        1.0
# 2           Emas            NaN   2018        1.0
# 3           Emas            NaN   2018        1.0
# 4           Emas            NaN   2022        1.0
# ...          ...            ...    ...        ...
# 1482  Partisipan            NaN   2015        NaN
# 1483  Partisipan            NaN   2017        NaN
# 1484  Partisipan            NaN   2014        NaN
# 1485  Partisipan            NaN   2021        NaN
# 1486  Partisipan            NaN   2019        NaN
#
# [1487 rows x 13 columns]

# %%
kategori_sma_inf_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1487 entries, 0 to 1486
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nama Peserta     1487 non-null   object
#  1   Gender           1487 non-null   object
#  2   Sekolah          1487 non-null   object
#  3   Provinsi         1487 non-null   object
#  4   Kab/Kota         1487 non-null   object
#  5   Bidang           1487 non-null   object
#  6   Jenjang Lomba    1487 non-null   object
#  7   Jenjang Sekolah  1487 non-null   object
#  8   Kelas            1436 non-null   float64
#  9   Medali           1487 non-null   object
#  10  Prize Tambahan   16 non-null     object
#  11  Tahun            1487 non-null   int64
#  12  Peringkat        481 non-null    float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 151.2+ KB

# %%
# kategori_sma_inf_sorted

prize_tambahan_sorted = kategori_sma_inf_sorted.sort_values(by=['Peringkat', 'Prize Tambahan'], na_position='last')

prize_tambahan_sorted.drop(columns=['Peringkat'], inplace=True)
prize_tambahan_sorted.reset_index(drop=True, inplace=True)
prize_tambahan_sorted
# Out:
#                     Nama Peserta Gender  \
# 0                  Nathan Azaria      L
# 1         Jonathan Irvin Gunawan      L
# 2                  Umar Alfarouk      L
# 3           Stacia Edina Johanna      P
# 4         Franklin Filbert Irwan      L
# ...                          ...    ...
# 1482   Muhammad Salman Al-Farisi      L
# 1483  Shalahuddin Akbar Aviecena      L
# 1484                   A R Yamin      L
# 1485         Radhya Cahya Kusuma      L
# 1486          Zikru Akbar Isnain      P
#
#                                         Sekolah          Provinsi  \
# 0                             SMAN 2 Purwokerto       Jawa Tengah
# 1             SMA Kristen BPK Penabur 1 Bandung        Jawa Barat
# 2                           SMP Pribadi Bandung        Jawa Barat
# 3                           SMA Kristen Petra 3        Jawa Timur
# 4                     SMA Darma Yudha Pekanbaru              Riau
# ...                                         ...               ...
# 1482                           SMPN 2 Pamekasan        Jawa Timur
# 1483  SMA Yayasan Pendidikan Vidya Dahana Patra  Kalimantan Timur
# 1484                           SMPN 2 Pamekasan        Jawa Timur
# 1485                          SMPN 8 Yogyakarta     DI Yogyakarta
# 1486                        SMAN 8 Kota Ternate      Maluku Utara
#
#              Kab/Kota       Bidang Jenjang Lomba Jenjang Sekolah  Kelas  \
# 0       Kab. Banyumas  Informatika           SMA             SMA   10.0
# 1        Kota Bandung  Informatika           SMA             SMA   10.0
# 2        Kota Bandung  Informatika           SMA             SMP    9.0
# 3       Kota Surabaya  Informatika           SMA             SMA   10.0
# 4      Kota Pekanbaru  Informatika           SMA             SMA   10.0
# ...               ...          ...           ...             ...    ...
# 1482   Kab. Pamekasan  Informatika           SMA             SMP    9.0
# 1483     Kota Bontang  Informatika           SMA             SMA   11.0
# 1484   Kab. Pamekasan  Informatika           SMA             SMP    9.0
# 1485  Kota Yogyakarta  Informatika           SMA             SMP    9.0
# 1486     Kota Ternate  Informatika           SMA             SMA   11.0
#
#           Medali            Prize Tambahan  Tahun
# 0           Emas           Best Paper Test   2011
# 1           Emas     Best Programming Test   2011
# 2           Emas    Kontestan Muda Terbaik   2013
# 3           Emas  Kontestan Wanita Terbaik   2014
# 4           Emas            Perfect Scorer   2024
# ...          ...                       ...    ...
# 1482  Partisipan                       NaN   2015
# 1483  Partisipan                       NaN   2017
# 1484  Partisipan                       NaN   2014
# 1485  Partisipan                       NaN   2021
# 1486  Partisipan                       NaN   2019
#
# [1487 rows x 12 columns]

# %%
provinsi_sumatra = ['Aceh', 'Sumatera Utara', 'Sumatera Barat', 
                    'Riau', 'Kepulauan Riau', 'Jambi', 'Bengkulu', 'Sumatera Selatan',
                    'Bangka Belitung', 'Lampung']
provinsi_jawa  = ['Banten', 'DKI Jakarta', 'Jawa Barat', 'Jawa Tengah', 'DI Yogyakarta', 'Jawa Timur']
provinsi_kalimatan = ['Kalimantan Barat', 'Kalimantan Tengah', 'Kalimantan Selatan', 'Kalimantan Timur', 'Kalimantan Utara']
provinsi_sulawesi = ['Sulawesi Utara', 'Sulawesi Barat', 'Sulawesi Tengah', 'Sulawesi Selatan', 'Sulawesi Tenggara', 'Gorontalo']
ntt_ntb_bali_provinsi = ['Bali', 'Nusa Tenggara Barat', 'Nusa Tenggara Timur']
provinsi_maluku = ['Maluku', 'Maluku Utara']
provinsi_papua = ['Papua', 'Papua Barat Daya', 'Papua Barat', 'Papua Tengah', 'Papua Pegunungan', 'Papua Selatan']

# %%
plt.figure(figsize=(18 , 12))
plt.title('Jumlah peserta OSN bidang informatika SMA & SMP berdasarkan provinsi')
kategori_sma_inf_sorted['Provinsi'].value_counts().sort_values().plot(kind='barh', color='skyblue')
plt.show()

# %%
jumlah_medali = kategori_sma_inf_sorted.groupby('Medali').size()
jumlah_medali
# Out:
# Medali
# Emas            81
# Partisipan    1006
# Perak          161
# Perunggu       239
# dtype: int64

# %%
jumlah_medali = kategori_sma_inf_sorted['Medali'].value_counts()

plt.figure(figsize=(8 , 5))
jumlah_medali.plot(kind='bar', color='skyblue')
plt.title('Jumlah Peserta Berdasarkan Medali')

plt.xlabel('Jenis Medali')
plt.ylabel('Jumlah Peserta')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Menampilkan diagram
plt.show()

# %%
jumlah_kategori_sekolah =  kategori_sma_inf_sorted['Jenjang Sekolah'].value_counts()
jumlah_kategori_sekolah
# Out:
# Jenjang Sekolah
# SMA    1422
# SMP      65
# Name: count, dtype: int64

# %%
jumlah_gender = kategori_sma_inf_sorted['Gender'].value_counts()
jumlah_gender
# Out:
# Gender
# L    1281
# P     206
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8 , 6))
plt.pie(kategori_sma_inf_sorted['Gender'].value_counts(), labels=kategori_sma_inf_sorted['Gender'].value_counts().index, autopct='%1.1f%%', startangle=90, colors=['red','blue'])
plt.title('Distribusi jumlah peserta Laki-Laki dan Perempuan')
plt.axis('equal')
plt.show()

# %%
prize_kategori_jumlah =  kategori_sma_inf_sorted['Prize Tambahan'].value_counts()
prize_kategori_jumlah
# Out:
# Prize Tambahan
# Kontestan Wanita Terbaik                         2
# Terbaik Wilayah Kalimantan                       2
# Terbaik Wilayah Jawa                             1
# Best Paper Test                                  1
# Best Programming Test                            1
# Perfect Scorer                                   1
# Praktikum Terbaik                                1
# Kontestan Muda Terbaik                           1
# Teori Terbaik, Peserta Putri Terbaik             1
# Kontesta Muda Terbaik                            1
# Kontestan Terbaik untuk Kategori Soal Kreatif    1
# Terbaik Wilayah Sumatera                         1
# Terbaik Wilayah Sulawesi                         1
# Terbaik Wilayah Bali dan Nusa Tenggara           1
# Name: count, dtype: int64

# %%
tabel_prize_nama = kategori_sma_inf_sorted.groupby('Prize Tambahan')['Nama Peserta'].apply(list).reset_index()


tabel_prize_nama = tabel_prize_nama.explode('Nama Peserta').reset_index(drop=True)

tabel_prize_nama = tabel_prize_nama[['Nama Peserta', 'Prize Tambahan']]

tabel_prize_nama = tabel_prize_nama.merge(kategori_sma_inf_sorted[['Nama Peserta', 'Provinsi']], on='Nama Peserta', how='left')
tabel_prize_nama
# Out:
#                       Nama Peserta  \
# 0                    Nathan Azaria
# 1           Jonathan Irvin Gunawan
# 2           Jonathan Irvin Gunawan
# 3                     Sergio Vieri
# 4                     Sergio Vieri
# 5                    Umar Alfarouk
# 6    I Gusti Ngurah Putra Sattvika
# 7             Stacia Edina Johanna
# 8             Stacia Edina Johanna
# 9                     Wynne Wijaya
# 10                    Wynne Wijaya
# 11          Franklin Filbert Irwan
# 12          Franklin Filbert Irwan
# 13          Franklin Filbert Irwan
# 14                 Felik Junvianto
# 15                 Jessica Handojo
# 16  Dewangga Winasforcepta Winardi
# 17             Ammar Fathin Sabili
# 18                  Steven Novaryo
# 19           Aulia Astrico Pratama
# 20           Aulia Astrico Pratama
# 21          Ibrohim Kholilul Islam
# 22                           Peter
# 23                           Peter
#
#                                    Prize Tambahan          Provinsi
# 0                                 Best Paper Test       Jawa Tengah
# 1                           Best Programming Test        Jawa Barat
# 2                           Best Programming Test       Jawa Tengah
# 3                           Kontesta Muda Terbaik        Jawa Timur
# 4                           Kontesta Muda Terbaik        Jawa Timur
# 5                          Kontestan Muda Terbaik        Jawa Barat
# 6   Kontestan Terbaik untuk Kategori Soal Kreatif              Bali
# 7                        Kontestan Wanita Terbaik        Jawa Timur
# 8                        Kontestan Wanita Terbaik        Jawa Timur
# 9                        Kontestan Wanita Terbaik  Sulawesi Selatan
# 10                       Kontestan Wanita Terbaik  Sulawesi Selatan
# 11                                 Perfect Scorer              Riau
# 12                                 Perfect Scorer              Riau
# 13                                 Perfect Scorer              Riau
# 14                              Praktikum Terbaik            Banten
# 15           Teori Terbaik, Peserta Putri Terbaik       DKI Jakarta
# 16         Terbaik Wilayah Bali dan Nusa Tenggara              Bali
# 17                           Terbaik Wilayah Jawa       Jawa Tengah
# 18                     Terbaik Wilayah Kalimantan  Kalimantan Barat
# 19                     Terbaik Wilayah Kalimantan  Kalimantan Timur
# 20                     Terbaik Wilayah Kalimantan  Kalimantan Timur
# 21                       Terbaik Wilayah Sulawesi         Gorontalo
# 22                       Terbaik Wilayah Sumatera    Sumatera Utara
# 23                       Terbaik Wilayah Sumatera    Sumatera Utara

# %%
data ={
    'Tahun': [2021, 2019, 2018, 2018, 2022, 2015, 2017, 2014, 2021, 2019]
}

tahun = kategori_sma_inf_sorted['Tahun'].drop_duplicates()
jumlah_peserta_per_tahun = kategori_sma_inf_sorted['Tahun'].value_counts().sort_index()
jumlah_peserta_per_tahun
# Out:
# Tahun
# 2009    110
# 2010    109
# 2011     90
# 2012     90
# 2013     96
# 2014     95
# 2015     75
# 2016     87
# 2017     76
# 2018     85
# 2019     74
# 2020    100
# 2021    100
# 2022    100
# 2023    100
# 2024    100
# Name: count, dtype: int64

# %%
# Membuat grafik garis
plt.figure(figsize=(10, 6))
plt.plot(jumlah_peserta_per_tahun.index, jumlah_peserta_per_tahun.values, marker='o', linestyle='-', color='r')
plt.title('CHART LINE PESERTA OSN BIDANG INFORMATIKA TAHUN 2009-2024')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Peserta')
plt.xticks(jumlah_peserta_per_tahun.index)  
plt.grid()


plt.tight_layout()
plt.show()

# %%
x_values = jumlah_peserta_per_tahun.index
y_values = jumlah_peserta_per_tahun.values.flatten() 

plt.figure(figsize=(10, 6))
plt.scatter(x=x_values, y=y_values, color='b', marker='o')
plt.title('DIAGRAM PENCAR PESERTA OSN BIDANG INFORMATIKA TAHUN 2009-2024')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Peserta')
plt.xticks(x_values)
plt.grid()

slope, intercept = np.polyfit(x_values, y_values, 1) 

regression_line = slope * x_values + intercept

plt.plot(x_values, regression_line, color='r', linestyle='--', label='Garis Regresi')
plt.legend()

korelasi = np.corrcoef(x_values, y_values)[0][1]
plt.text(2010, max(y_values) * 0.8,
         f'Korelasi: {korelasi:.2f}', fontsize=12)

plt.tight_layout()
plt.show()
